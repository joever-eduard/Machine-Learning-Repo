# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv("data/movie_metadata_cleaned.csv")

# %%
data.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    num_user_for_reviews language country  content_rating       budget  \
# 0                3054.0  English     USA           PG-13  237000000.0
# 1                1238.0  English     USA           PG-13  300000000.0
#
#   title_year  actor_2_facebook_likes imdb_score aspect_ratio  \
# ...

# %% [markdown]
# ## Get the top 10 directors with most movies directed and use a boxplot for their gross earnings

# %%
top_10_directors = data['director_name'].value_counts()[:11]
print("Top 10 directors based on the number of movies directed are:\n")
name = top_10_directors.index
count = top_10_directors.values
for i in range(1, 11):
     print(f' {i}: {name[i]} with {count[i]} movies directed')
# Out:
# Top 10 directors based on the number of movies directed are:
#
#  1: Steven Spielberg with 26 movies directed
#  2: Woody Allen with 22 movies directed
#  3: Martin Scorsese with 20 movies directed
#  4: Clint Eastwood with 20 movies directed
#  5: Ridley Scott with 17 movies directed
#  6: Tim Burton with 16 movies directed
#  7: Steven Soderbergh with 16 movies directed
#  8: Spike Lee with 16 movies directed
#  9: Renny Harlin with 15 movies directed
#  10: Oliver Stone with 14 movies directed

# %% [markdown]
# ## Plot the following variables in one graph:
#
# - num_critic_for_reviews
# - IMDB score
# - gross

# %%
plt.plot(data["num_critic_for_reviews"], data["imdb_score"], data["gross"])
plt.show()

# %% [markdown]
# ## Compute Sales (Gross - Budget), add it as another column

# %%
sales = data['gross'] - data['budget']
data['sales'] = sales
data
# Out:
#       Unnamed: 0                                        movie_title  color  \
# 0              0                                          b'Avatar'  Color
# 1              1        b"Pirates of the Caribbean: At World's End"  Color
# 2              2                                         b'Spectre'  Color
# 3              3                           b'The Dark Knight Rises'  Color
# 4              4  b'Star Wars: Episode VII - The Force Awakens  ...      0
# ...          ...                                                ...    ...
# 5039        5039                       b'The Following            '  Color
# 5040        5040                            b'A Plague So Pleasant'  Color
# 5041        5041                                b'Shanghai Calling'  Color
# 5042        5042                               b'My Date with Drew'  Color
# 5043        5043                             b'Starting Over Again'      0
#
#           director_name  num_critic_for_reviews  duration  \
# ...

# %% [markdown]
# ## Which directors garnered the most total sales?

# %%
top_sales = data.sort_values(by='sales', ascending = False)
top_director = top_sales[:5]
top_director
# Out:
#       Unnamed: 0                            movie_title  color  \
# 0              0                              b'Avatar'  Color
# 29            29                      b'Jurassic World'  Color
# 26            26                             b'Titanic'  Color
# 3024        3024  b'Star Wars: Episode IV - A New Hope'  Color
# 3080        3080          b'E.T. the Extra-Terrestrial'  Color
#
#          director_name  num_critic_for_reviews  duration  \
# 0        James Cameron                   723.0     178.0
# 29     Colin Trevorrow                   644.0     124.0
# 26       James Cameron                   315.0     189.0
# 3024      George Lucas                   282.0     125.0
# 3080  Steven Spielberg                   215.0     120.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 29                      365.0                  1000.0        Judy Greer
# ...

# %% [markdown]
# ## Plot sales and average likes as a scatterplot. Fit it with a line.

# %%
average_likes = data['movie_facebook_likes'].mean()
data['average_likes'] = average_likes
fig = plt.figure(figsize=(15,8))
plt.scatter(data['sales'], data['average_likes'])
plt.show()

# %% [markdown]
# ## Which of these genres are the most profitable? Plot their sales using different histograms, superimposed in the same axis.
#
# - Romance
# - Comedy
# - Action
# - Fantasy

# %%
fig = plt.figure(figsize=(15,8))
plt.xlabel('Profit')
plt.ylabel('frequency')
plt.hist(data[data['genres'].str.contains('Comedy')]["sales"], color="green", label="Comedy")
plt.hist(data[data['genres'].str.contains('Romance')]["sales"], color="violet", label="Romance")
plt.hist(data[data['genres'].str.contains('Action')]["sales"], color="red", label="Action")
plt.hist(data[data['genres'].str.contains('Fantasy')]["sales"], color="black", label="Fantasy")
plt.legend()
plt.show()

# %% [markdown]
# ## For each of movie, compute average likes of the three actors and store it as a new variable
#
# Read up on the mean function.
#
# Store it as a new column, average_actor_likes.

# %% [markdown]
# ## Copying the whole dataframe

# %%
df = data.copy()
df.head()
cleaned_data = data.fillna(0)
max = cleaned_data['duration'].max()
min = cleaned_data['duration'].min()
cleaned_data['nm_duration'] = (cleaned_data['duration'] - min) / (max-min)
cleaned_data
# Out:
#       Unnamed: 0                                        movie_title  color  \
# 0              0                                          b'Avatar'  Color
# 1              1        b"Pirates of the Caribbean: At World's End"  Color
# 2              2                                         b'Spectre'  Color
# 3              3                           b'The Dark Knight Rises'  Color
# 4              4  b'Star Wars: Episode VII - The Force Awakens  ...      0
# ...          ...                                                ...    ...
# 5039        5039                       b'The Following            '  Color
# 5040        5040                            b'A Plague So Pleasant'  Color
# 5041        5041                                b'Shanghai Calling'  Color
# 5042        5042                               b'My Date with Drew'  Color
# 5043        5043                             b'Starting Over Again'      0
#
#           director_name  num_critic_for_reviews  duration  \
# ...

# %% [markdown]
# ## Min-Max Normalization
#
# Normalization is a technique often applied as part of data preparation for machine learning. The goal of normalization is to change the values of numeric columns in the dataset to a common scale, without distorting differences in the ranges of values. For machine learning, every dataset does not require normalization. It is required only when features have different ranges.
#
# The min-max approach (often called normalization) rescales the feature to a hard and fast range of [0,1] by subtracting the minimum value of the feature then dividing by the range. We can apply the min-max scaling in Pandas using the .min() and .max() methods.
#
# $$
# x_{scaled} = \frac{x-x_{min}}{x_{max}-x_{min}}
# $$

# %% [markdown]
# ### Normalize each numeric column (those that have types integer or float) of the copied dataframe (df)

# %%
# Out:
# pandas.core.series.Series
